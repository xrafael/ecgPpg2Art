# %%
reset -sf

# %%
import sys
import os
import numpy as np 
import pandas as pd
from pathlib import Path

# univariate mlp example
from numpy import array

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from keras import optimizers
from keras import regularizers
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasRegressor
from keras.layers import Dense, BatchNormalization, Dropout
from sklearn.preprocessing import StandardScaler
from sklearn.externals import joblib

import matplotlib.pyplot as plt
# Out:
# /home/administrador/anaconda3/envs/deeplung/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
PATH = Path("../data/")

# %%
scaler = joblib.load(PATH/'train_scaler_x.pkl')
# Out:
# /home/administrador/anaconda3/envs/deeplung/lib/python3.6/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator StandardScaler from version 0.20.1 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
dfX_Train = np.load(PATH/'train_x.npy')
dfX_Val = np.load(PATH/'val_x.npy') 
dfX_Test = np.load(PATH/'test_x.npy')
dfY_Train = np.load(PATH/'train_y.npy')
dfY_Val = np.load(PATH/'val_y.npy')
dfY_Test = np.load(PATH/'test_y.npy')

#dfX_Train = np.vstack((dfX_Train, dfX_Val))
#dfY_Train = np.vstack((dfY_Train, dfY_Val))

print(dfX_Train.shape, dfY_Train.shape)
print(dfX_Val.shape, dfY_Val.shape)
print(dfX_Test.shape, dfY_Test.shape)
print(dfX_Train[0,:10])
# Out:
# (8126, 2500) (8126, 1250)
# (1016, 2500) (1016, 1250)
# (1016, 2500) (1016, 1250)
# [1.0743 1.0802 1.1212 1.2092 1.35   1.5396 1.7664 2.0088 2.2473 2.4399]

# %%
history=None
freq = 125
ini = 0 #freq
dim = freq * 2
ecg = 1250

# %%
#Normalize y
rng = (dfY_Train[:,ini:ini+dim].max(axis=1) - dfY_Train[:,ini:ini+dim].min(axis=1))
trainY_n = np.array([dfY_Train [:,i] - dfY_Train[:,ini:ini+dim].min(axis=1) 
                       for i in range(ini,ini+dim)]) / rng

rng = (dfY_Val[:,ini:ini+dim].max(axis=1) - dfY_Val[:,ini:ini+dim].min(axis=1))
valY_n = np.array([dfY_Val [:,i] - dfY_Val[:,ini:ini+dim].min(axis=1) 
                       for i in range(ini,ini+dim)]) / rng

rng = (dfY_Test[:,ini:ini+dim].max(axis=1) - dfY_Test[:,ini:ini+dim].min(axis=1))
testY_n = np.array([dfY_Test [:,i] - dfY_Test[:,ini:ini+dim].min(axis=1) 
                       for i in range(ini,ini+dim)]) / rng

trainY_n = trainY_n.T
valY_n = valY_n.T
testY_n = testY_n.T

# %%
#Normalize X
rng = (dfX_Train[:,ini:ini+dim].max(axis=1) - dfX_Train[:,ini:ini+dim].min(axis=1))
trainX_0_n = np.array([dfX_Train [:,i] - dfX_Train[:,ini:ini+dim].min(axis=1) 
                       for i in range(ini,ini+dim)]) / rng

rng = (dfX_Train[:,ecg+ini:ini+ecg+dim].max(axis=1) - dfX_Train[:,ecg+ini:ini+ecg+dim].min(axis=1))
trainX_1_n = np.array([dfX_Train [:,i] - dfX_Train[:,ini+ecg:ini+ecg+dim].min(axis=1) for i in range(ini+ecg,ini+ecg+dim)]) / rng

rng = (dfX_Val[:,ini:ini+dim].max(axis=1) - dfX_Val[:,ini:ini+dim].min(axis=1))
valX_0_n = np.array([dfX_Val [:,i] - dfX_Val[:,ini:ini+dim].min(axis=1) 
                       for i in range(ini,ini+dim)]) / rng

rng = (dfX_Val[:,ecg+ini:ini+ecg+dim].max(axis=1) - dfX_Val[:,ecg+ini:ini+ecg+dim].min(axis=1))
valX_1_n = np.array([dfX_Val [:,i] - dfX_Val[:,ini+ecg:ini+ecg+dim].min(axis=1) for i in range(ini+ecg,ini+ecg+dim)]) / rng

rng = (dfX_Test[:,ini:ini+dim].max(axis=1) - dfX_Test[:,ini:ini+dim].min(axis=1))
testX_0_n = np.array([dfX_Test [:,i] - dfX_Test[:,ini:ini+dim].min(axis=1) 
                       for i in range(ini,ini+dim)]) / rng

rng = (dfX_Test[:,ecg+ini:ini+ecg+dim].max(axis=1) - dfX_Test[:,ecg+ini:ini+ecg+dim].min(axis=1))
testX_1_n = np.array([dfX_Test [:,i] - dfX_Test[:,ini+ecg:ini+ecg+dim].min(axis=1) for i in range(ini+ecg,ini+ecg+dim)]) / rng

trainX_0_n = trainX_0_n.T
trainX_1_n = trainX_1_n.T
valX_0_n = valX_0_n.T
valX_1_n = valX_1_n.T
testX_0_n = testX_0_n.T 
testX_1_n = testX_1_n.T

print(trainX_0_n.shape,trainX_1_n.shape)
print(valX_0_n.shape,valX_1_n.shape)
print(testX_0_n.shape,testX_1_n.shape)
# Out:
# (8126, 250) (8126, 250)
# (1016, 250) (1016, 250)
# (1016, 250) (1016, 250)

# %%
ax = plt.subplot(3,2,1)
ax.plot(valX_0_n[0,:])
ax = plt.subplot(3,2,2)
ax.plot(dfX_Val[0,ini:ini+dim])
ax = plt.subplot(3,2,3)
ax.plot(valX_1_n[0,:])
ax = plt.subplot(3,2,4)
ax.plot(dfX_Val[0,ini+ecg:ini+ecg+dim])
ax = plt.subplot(3,2,5)
ax.plot(valY_n[0,:])
ax = plt.subplot(3,2,6)
ax.plot(dfY_Val[0,ini:ini+dim])

plt.show()

# %%
#Definition of the model

# %%
model = Sequential()
model.add(Dense(dim*2, activation='relu', input_dim=dim*2))
model.add(Dropout(0.7))
model.add(BatchNormalization())
model.add(Dense(dim*2, activation='relu', input_dim=dim*2))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Dense(dim, activation='relu', input_dim=dim*2))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Dense(dim, activation='relu', input_dim=dim))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Dense(dim))
model.compile(optimizer=optimizers.Adam(lr=0.001), loss='mse')

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 500)               2000
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 500)               2000
# _________________________________________________________________
# dense_3 (Dense)              (None, 250)               125250
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 250)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 250)               1000
# _________________________________________________________________
# dense_4 (Dense)              (None, 250)               62750
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 250)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 250)               1000
# _________________________________________________________________
# dense_5 (Dense)              (None, 250)               62750
# =================================================================
# Total params: 757,750
# Trainable params: 754,750
# Non-trainable params: 3,000
# _________________________________________________________________

# %%
print(np.hstack((trainX_0_n, trainX_1_n)).shape)
print(np.hstack((valX_0_n, valX_1_n)).shape)
model.compile(optimizer=optimizers.Adam(lr=0.001), loss='mse')
model.fit(np.hstack((trainX_0_n, trainX_1_n)), trainY_n, epochs=100, verbose=1, 
          validation_data=(np.hstack((valX_0_n, valX_1_n)),valY_n), batch_size=128)
# Out:
# (8126, 500)
# (1016, 500)
# Train on 8126 samples, validate on 1016 samples
# Epoch 1/100
# 8126/8126 [==============================] - 2s 297us/step - loss: 0.7424 - val_loss: 0.1521
# Epoch 2/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.2429 - val_loss: 0.0682
# Epoch 3/100
# 8126/8126 [==============================] - 1s 77us/step - loss: 0.1186 - val_loss: 0.0595
# Epoch 4/100
# 8126/8126 [==============================] - 1s 77us/step - loss: 0.0822 - val_loss: 0.0512
# Epoch 5/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0685 - val_loss: 0.0459
# Epoch 6/100
# 8126/8126 [==============================] - 1s 77us/step - loss: 0.0626 - val_loss: 0.0414
# Epoch 7/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0596 - val_loss: 0.0387
# Epoch 8/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0578 - val_loss: 0.0379
# Epoch 9/100
# 8126/8126 [==============================] - 1s 77us/step - loss: 0.0559 - val_loss: 0.0376
# Epoch 10/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0549 - val_loss: 0.0365
# Epoch 11/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0538 - val_loss: 0.0358
# Epoch 12/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0527 - val_loss: 0.0348
# Epoch 13/100
# 8126/8126 [==============================] - 1s 77us/step - loss: 0.0521 - val_loss: 0.0343
# Epoch 14/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0512 - val_loss: 0.0343
# Epoch 15/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0507 - val_loss: 0.0337
# Epoch 16/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0499 - val_loss: 0.0331
# Epoch 17/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0494 - val_loss: 0.0326
# Epoch 18/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0491 - val_loss: 0.0324
# Epoch 19/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0482 - val_loss: 0.0315
# Epoch 20/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0478 - val_loss: 0.0312
# Epoch 21/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0477 - val_loss: 0.0314
# Epoch 22/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0469 - val_loss: 0.0306
# Epoch 23/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0465 - val_loss: 0.0309
# Epoch 24/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0461 - val_loss: 0.0301
# Epoch 25/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0459 - val_loss: 0.0302
# Epoch 26/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0452 - val_loss: 0.0298
# Epoch 27/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0454 - val_loss: 0.0304
# Epoch 28/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0451 - val_loss: 0.0299
# Epoch 29/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0447 - val_loss: 0.0296
# Epoch 30/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0447 - val_loss: 0.0294
# Epoch 31/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0440 - val_loss: 0.0292
# Epoch 32/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0437 - val_loss: 0.0292
# Epoch 33/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0440 - val_loss: 0.0290
# Epoch 34/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0435 - val_loss: 0.0288
# Epoch 35/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0434 - val_loss: 0.0283
# Epoch 36/100
# 8126/8126 [==============================] - 1s 77us/step - loss: 0.0433 - val_loss: 0.0294
# Epoch 37/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0433 - val_loss: 0.0288
# Epoch 38/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0429 - val_loss: 0.0287
# Epoch 39/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0434 - val_loss: 0.0283
# Epoch 40/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0428 - val_loss: 0.0285
# Epoch 41/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0427 - val_loss: 0.0285
# Epoch 42/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0423 - val_loss: 0.0285
# Epoch 43/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0423 - val_loss: 0.0281
# Epoch 44/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0418 - val_loss: 0.0280
# Epoch 45/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0424 - val_loss: 0.0279
# Epoch 46/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0421 - val_loss: 0.0283
# Epoch 47/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0419 - val_loss: 0.0276
# Epoch 48/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0415 - val_loss: 0.0274
# Epoch 49/100
# 8126/8126 [==============================] - 1s 77us/step - loss: 0.0415 - val_loss: 0.0278
# Epoch 50/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0417 - val_loss: 0.0283
# Epoch 51/100
# 8126/8126 [==============================] - 1s 79us/step - loss: 0.0414 - val_loss: 0.0273
# Epoch 52/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0414 - val_loss: 0.0279
# Epoch 53/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0414 - val_loss: 0.0276
# Epoch 54/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0411 - val_loss: 0.0275
# Epoch 55/100
# 8126/8126 [==============================] - 1s 77us/step - loss: 0.0413 - val_loss: 0.0270
# Epoch 56/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0406 - val_loss: 0.0275
# Epoch 57/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0409 - val_loss: 0.0277
# Epoch 58/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0404 - val_loss: 0.0268
# Epoch 59/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0406 - val_loss: 0.0271
# Epoch 60/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0404 - val_loss: 0.0273
# Epoch 61/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0402 - val_loss: 0.0273
# Epoch 62/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0403 - val_loss: 0.0270
# Epoch 63/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0403 - val_loss: 0.0276
# Epoch 64/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0402 - val_loss: 0.0269
# Epoch 65/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0401 - val_loss: 0.0271
# Epoch 66/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0402 - val_loss: 0.0267
# Epoch 67/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0397 - val_loss: 0.0265
# Epoch 68/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0396 - val_loss: 0.0272
# Epoch 69/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0395 - val_loss: 0.0269
# Epoch 70/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0394 - val_loss: 0.0268
# Epoch 71/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0399 - val_loss: 0.0268
# Epoch 72/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0395 - val_loss: 0.0263
# Epoch 73/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0393 - val_loss: 0.0266
# Epoch 74/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0391 - val_loss: 0.0266
# Epoch 75/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0393 - val_loss: 0.0267
# Epoch 76/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0392 - val_loss: 0.0268
# Epoch 77/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0390 - val_loss: 0.0260
# Epoch 78/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0388 - val_loss: 0.0259
# Epoch 79/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0386 - val_loss: 0.0268
# Epoch 80/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0390 - val_loss: 0.0265
# Epoch 81/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0390 - val_loss: 0.0262
# Epoch 82/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0387 - val_loss: 0.0268
# Epoch 83/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0388 - val_loss: 0.0264
# Epoch 84/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0387 - val_loss: 0.0264
# Epoch 85/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0387 - val_loss: 0.0264
# Epoch 86/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0386 - val_loss: 0.0262
# Epoch 87/100
# 8126/8126 [==============================] - 1s 77us/step - loss: 0.0389 - val_loss: 0.0262
# Epoch 88/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0384 - val_loss: 0.0266
# Epoch 89/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0387 - val_loss: 0.0265
# Epoch 90/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0387 - val_loss: 0.0262
# Epoch 91/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0382 - val_loss: 0.0261
# Epoch 92/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0383 - val_loss: 0.0263
# Epoch 93/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0382 - val_loss: 0.0259
# Epoch 94/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0381 - val_loss: 0.0261
# Epoch 95/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0379 - val_loss: 0.0260
# Epoch 96/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0378 - val_loss: 0.0260
# Epoch 97/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0379 - val_loss: 0.0256
# Epoch 98/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0379 - val_loss: 0.0259
# Epoch 99/100
# 8126/8126 [==============================] - 1s 79us/step - loss: 0.0377 - val_loss: 0.0261
# Epoch 100/100
# 8126/8126 [==============================] - 1s 78us/step - loss: 0.0377 - val_loss: 0.0261

# %%
# Save the weights
model.save_weights('nn_1.h5')

# Save the model architecture
with open('nn_1.json', 'w') as f:
    f.write(model.to_json())

# %%
#Visualize

# %%
ix=1000
print(np.expand_dims(np.hstack((testX_0_n[ix,:],testX_1_n[ix,:])).reshape(1,-1), axis=2).shape)

plt.figure(figsize=(12,3))
plt.plot(testX_0_n[ix,:].reshape(1,-1).T, c="g", label="PPG")
plt.legend()
plt.show()

plt.figure(figsize=(12,3))
plt.plot(testX_1_n[ix,:].reshape(1,-1).T, c="g", label="ECG")
plt.legend()
plt.show()

#Predicted vs real
plt.figure(figsize=(12,3))
plt.plot(model.predict(np.hstack((testX_0_n[ix,:],testX_1_n[ix,:])).reshape(1,-1)).T, label="pred_ART")
plt.plot(testY_n[ix,:].reshape(1,-1).T, c="g", label="real_ART")
plt.legend()
plt.show()
# Out:
# (1, 500, 1)
